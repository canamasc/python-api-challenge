# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json
# Import API key
from api_keys import g_key

# %%
# Load csv
path = os.path.join('..', 'weatherpy', 'weatherdata.csv' ) 
df = pd.read_csv(path)
df.head()
# Out:
#    Unnamed: 0       Cities Country  Temp (F)  Latitude  Longitude  \
# 0           0      sechura      PE     67.33   -5.5569   -80.8222
# 1           1  port alfred      ZA     55.81  -33.5906    26.8910
# 2           2      ushuaia      AR     38.86  -54.8000   -68.3000
# 3           3       barrow      US     35.62   71.2906  -156.7887
# 4           4      bubaque      GW     80.55   11.2833   -15.8333
#
#    Cloudiness (%)  Humidity (%)  Wind Speed (mph)        Date
# 0              62            76             10.94  1627050364
# 1              55            58             11.14  1627050365
# 2              75            81             14.97  1627050366
# 3              90            93             16.11  1627050367
# 4              98            80             14.05  1627050076

# %%
# Get rid of duplicate index column
df = df.drop(columns='Unnamed: 0')

# %%
# configure gmaps
gmaps.configure(api_key=g_key)

coords = df[(['Latitude', 'Longitude'])]

# %%
# Customize the size of the figure
figure_layout = {
    'width': '700px',
    'height': '400px',
    'border': '1px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto'
}
fig = gmaps.figure(layout=figure_layout)

# Add the layer to the map
fig.add_layer(gmaps.heatmap_layer(coords,weights=df['Humidity (%)'], max_intensity = df['Humidity (%)'].max()))

fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='400px', margin='0 auto 0 auto', padding='1px', wi…

# %%
# Drop any rows that contain missing values
df_ideal = df.dropna()
# Limit max temp values, cloudiness values, and wind speed values for ideal vacation spots
df_ideal = df_ideal.loc[(df_ideal['Temp (F)'] <= 83.0) & (df_ideal['Temp (F)'] > 77.0)
                       & (df_ideal['Cloudiness (%)'] < 15) & (df_ideal['Wind Speed (mph)'] < 10.0) & 
                       (df_ideal['Wind Speed (mph)'] > 1.0)]
df_ideal
# Out:
#                   Cities Country  Temp (F)  Latitude  Longitude  \
# 5           saint george      US     80.35   37.1041  -113.5841
# 34         saint anthony      US     81.79   45.0205   -93.2180
# 52          ponta do sol      PT     81.72   32.6667   -17.1000
# 68                bethel      US     77.11   41.3712   -73.4140
# 92         stevens point      US     79.66   44.5236   -89.5746
# 111            owensboro      US     80.02   37.7742   -87.1133
# 134              shawnee      US     82.44   39.0500   -95.7669
# 167              lincoln      US     81.28   40.8000   -96.6670
# 186          springfield      US     80.35   37.2153   -93.2982
# 213               jasper      US     82.35   37.2001   -94.3502
# 222              douglas      US     81.14   41.3000   -96.1670
# 258                 mayo      US     79.43   38.8876   -76.5119
# 331              ardmore      US     81.39   34.1743   -97.1436
# 333            mporokoso      ZM     80.02   -9.3727    30.1250
# 346                aksay      RU     82.62   47.2600    39.8700
# 347         rapid valley      US     82.06   44.0625  -103.1463
# 358                  hof      DE     81.61   50.3167    11.9167
# 362            ascheberg      DE     81.43   51.7833     7.6167
# 384              bestobe      KZ     80.06   52.4994    73.0975
# 423              bemidji      US     80.64   47.4736   -94.8803
# 465  ignacio de la llave      MX     81.19   18.7167   -95.9833
# 482              ondjiva      AO     77.04  -17.0667    15.7333
# 486              mugango      TZ     82.58   -1.6833    33.7000
#
#      Cloudiness (%)  Humidity (%)  Wind Speed (mph)        Date
# 5                 1            80              1.99  1627050086
# 34                1            67              1.99  1627050390
# 52                0            65              2.93  1627050403
# 68                1            65              1.01  1627050415
# 92                1            81              5.75  1627050304
# 111               1            65              4.61  1627050447
# 134               1            74              1.01  1627050261
# 167               1            69              5.99  1627050337
# 186               1            85              4.00  1627050431
# 213               1            80              3.00  1627050524
# 222               1            74              7.00  1627050531
# 258               1            64              8.01  1627050558
# 331               1            78              5.99  1627050618
# 333               3            22              7.90  1627050620
# 346               6            42              8.01  1627050630
# 347               1            68              3.44  1627050631
# 358               0            45              4.61  1627050640
# 362               2            48              5.50  1627050592
# 384               0            33              7.81  1627050659
# 423               1            84              4.61  1627050689
# 465               0            75              3.80  1627050720
# 482               0            10              6.91  1627050734
# 486               5            37              8.61  1627050737

# %%
hotel_df = df_ideal.copy()
hotel_df['Hotel Name'] = ""

# Loop through ideal cities
for index,row in hotel_df.iterrows():
    city = row['Cities']
    # get coordinates in needed format
    lat1 = (hotel_df.loc[(hotel_df['Cities'] == city)]['Latitude']).astype(str)
    lon1 = (hotel_df.loc[(hotel_df['Cities'] == city)]['Longitude']).astype(str)
    loc = lat1 + ", " + lon1
    # set up a parameters dictionary
    params = {
    'location': loc,
    "radius": 5000,
    "type": "lodging",
    "key": g_key,
   # "rankby": "distance"
    }
    # base url
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # run a request using our params dictionary
    response = requests.get(base_url, params=params)
    
    # convert response to json
    places_data = response.json()
    try:
        hotel_df.loc[index,'Hotel Name'] = places_data["results"][0]["name"]
    except:
        print(f"Results for {city} not found.")
        

#Print the json (pretty printed) for last city to get structure idea
#print(json.dumps(places_data, indent=4, sort_keys=True))
hotel_df
# Out:
# Results for bestobe not found.
# Results for mugango not found.
#                   Cities Country  Temp (F)  Latitude  Longitude  \
# 5           saint george      US     80.35   37.1041  -113.5841
# 34         saint anthony      US     81.79   45.0205   -93.2180
# 52          ponta do sol      PT     81.72   32.6667   -17.1000
# 68                bethel      US     77.11   41.3712   -73.4140
# 92         stevens point      US     79.66   44.5236   -89.5746
# 111            owensboro      US     80.02   37.7742   -87.1133
# 134              shawnee      US     82.44   39.0500   -95.7669
# 167              lincoln      US     81.28   40.8000   -96.6670
# 186          springfield      US     80.35   37.2153   -93.2982
# 213               jasper      US     82.35   37.2001   -94.3502
# 222              douglas      US     81.14   41.3000   -96.1670
# 258                 mayo      US     79.43   38.8876   -76.5119
# 331              ardmore      US     81.39   34.1743   -97.1436
# 333            mporokoso      ZM     80.02   -9.3727    30.1250
# 346                aksay      RU     82.62   47.2600    39.8700
# 347         rapid valley      US     82.06   44.0625  -103.1463
# 358                  hof      DE     81.61   50.3167    11.9167
# 362            ascheberg      DE     81.43   51.7833     7.6167
# 384              bestobe      KZ     80.06   52.4994    73.0975
# 423              bemidji      US     80.64   47.4736   -94.8803
# 465  ignacio de la llave      MX     81.19   18.7167   -95.9833
# 482              ondjiva      AO     77.04  -17.0667    15.7333
# 486              mugango      TZ     82.58   -1.6833    33.7000
#
#      Cloudiness (%)  Humidity (%)  Wind Speed (mph)        Date  \
# 5                 1            80              1.99  1627050086
# 34                1            67              1.99  1627050390
# 52                0            65              2.93  1627050403
# 68                1            65              1.01  1627050415
# 92                1            81              5.75  1627050304
# 111               1            65              4.61  1627050447
# 134               1            74              1.01  1627050261
# 167               1            69              5.99  1627050337
# 186               1            85              4.00  1627050431
# 213               1            80              3.00  1627050524
# 222               1            74              7.00  1627050531
# 258               1            64              8.01  1627050558
# 331               1            78              5.99  1627050618
# 333               3            22              7.90  1627050620
# 346               6            42              8.01  1627050630
# 347               1            68              3.44  1627050631
# 358               0            45              4.61  1627050640
# 362               2            48              5.50  1627050592
# 384               0            33              7.81  1627050659
# 423               1            84              4.61  1627050689
# 465               0            75              3.80  1627050720
# 482               0            10              6.91  1627050734
# 486               5            37              8.61  1627050737
#
#                                             Hotel Name
# 5                          Best Western Plus Abbey Inn
# 34   Holiday Inn Express Roseville-St. Paul, an IHG...
# 52                                      Hotel do Campo
# 68                       Courtyard by Marriott Danbury
# 92    Fairfield Inn & Suites by Marriott Stevens Point
# 111                    Courtyard by Marriott Owensboro
# 134                   Fairfield Inn by Marriott Topeka
# 167   Courtyard by Marriott Lincoln Downtown/Haymarket
# 186         University Plaza Hotel & Convention Center
# 213                                  Guest House Motel
# 222                       Hilton Garden Inn Omaha West
# 258               Resorts Resource Group International
# 331                                Motel 6 Ardmore, OK
# 333                             Government Guest House
# 346                              Chernaya Zhemchuzhina
# 347      Fairfield Inn & Suites by Marriott Rapid City
# 358                                      Hotel Burghof
# 362                              Hotel Jagdschlösschen
# 384
# 423                       Hampton Inn & Suites Bemidji
# 465                                      Hotel Valeria
# 482                                          SOS Motel
# 486

# %%
# get coordinates as list of tuples


# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{Cities}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Latitude", "Longitude"]]
    
fig.add_layer(gmaps.marker_layer(locations, info_box_content = hotel_info))
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='400px', margin='0 auto 0 auto', padding='1px', wi…
