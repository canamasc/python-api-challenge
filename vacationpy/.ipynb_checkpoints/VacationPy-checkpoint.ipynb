# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json
# Import API key
from api_keys import g_key

# %%
# Load csv
path = os.path.join('..', 'weatherpy', 'weatherdata.csv' ) 
df = pd.read_csv(path)
df.head()
# Out:
#    Unnamed: 0       Cities Country  Temp (F)  Latitude  Longitude  \
# 0           0      sechura      PE     72.12   -5.5569   -80.8222
# 1           1  port alfred      ZA     60.46  -33.5906    26.8910
# 2           2      ushuaia      AR     37.02  -54.8000   -68.3000
# 3           3       barrow      US     39.22   71.2906  -156.7887
# 4           4      bubaque      GW     82.69   11.2833   -15.8333
#
#    Cloudiness (%)  Humidity (%)  Wind Speed (mph)        Date
# 0               1            64              6.22  1626797831
# 1              95            78             18.88  1626797603
# 2              75            69              4.61  1626797719
# 3              90            93             19.57  1626797775
# 4              19            75             10.60  1626797834

# %%
# Get rid of duplicate index column
df = df.drop(columns='Unnamed: 0')

# %%
# configure gmaps
gmaps.configure(api_key=g_key)

coords = df[(['Latitude', 'Longitude'])]

# %%
# Customize the size of the figure
figure_layout = {
    'width': '400px',
    'height': '300px',
    'border': '1px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto'
}
fig = gmaps.figure(layout=figure_layout)

# Add the layer to the map
fig.add_layer(gmaps.heatmap_layer(coords,df['Humidity (%)']))

#fig.add_layer(gmaps.heatmap_layer(coords, weights=df['Humidity (%)']))
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='300px', margin='0 auto 0 auto', padding='1px', wi…

# %%
# Drop any rows that contain missing values
df_ideal = df.dropna()
# Limit max temp values, cloudiness values, and wind speed values for ideal vacation spots
df_ideal = df_ideal.loc[(df_ideal['Temp (F)'] <= 83.0) & (df_ideal['Temp (F)'] > 77.0)
                       & (df_ideal['Cloudiness (%)'] < 15) & (df_ideal['Wind Speed (mph)'] < 10.0)]
df_ideal
# Out:
#             Cities Country  Temp (F)  Latitude  Longitude  Cloudiness (%)  \
# 52    ponta do sol      PT     77.72   32.6667   -17.1000               2
# 92   stevens point      US     81.39   44.5236   -89.5746               1
# 127      wiesbaden      DE     80.46   50.0833     8.2500               1
# 303         chaves      US     82.58   33.3834  -104.4505               1
# 338      winnenden      DE     78.12   48.8756     9.3982               0
# 437        ipameri      BR     82.27  -17.7219   -48.1597               1
# 450     livingston      GB     78.87   55.9029    -3.5226               0
# 482        ondjiva      AO     80.64  -17.0667    15.7333               0
# 490      pontalina      BR     82.74  -17.5250   -49.4472               2
#
#      Humidity (%)  Wind Speed (mph)        Date
# 52             70              1.32  1626797868
# 92             70              0.00  1626797881
# 127            40              1.01  1626797926
# 303            65              9.22  1626798058
# 338            45              4.00  1626798085
# 437            13              4.56  1626798162
# 450            74              9.22  1626798102
# 482            19              4.61  1626798201
# 490            10              4.52  1626798207

# %%
hotel_df = df_ideal.copy()
hotel_df['Hotel Name'] = 'PlaceHolder'

# Loop through ideal cities
for city in hotel_df['Cities']:
# set up a parameters dictionary
    lat1 = (hotel_df.loc[(hotel_df['Cities'] == city)]['Latitude']).astype(str)
    lon1 = (hotel_df.loc[(hotel_df['Cities'] == city)]['Longitude']).astype(str)
    loc = lat1 + ", " + lon1
   # print(loc)
    params = {
    'location': loc,
    #"location": hotel_df[(['Latitude', 'Longitude'])],
    "radius": 50000,
    "type": "lodging",
    "key": g_key
    }

# base url
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
    response = requests.get(base_url, params=params)
# convert response to json
    places_data = response.json()

# Print the json (pretty printed)
    print(json.dumps(places_data, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "Aap_uEBCsqt8sD3-EXAo_ba_r5q5b1PM1_ikyKbEMsG0MOXCC7RIUsAgPJYQ0_3jVe-fqBX3ooEsZs_SfJZ95p_lUV8b-3VWkvSVaEBe6p7fodD_BOoJj3dWTXrKLgB9c0AG-QQWugghigMaNOcp6-ORLumZoZFUBF9YcnbS1L3bQqizow7S8FbDpZW2d31T7pfZwPVF4-k4XGF7pKFHaqIEs0Fl8yw-L_X1_mCtZG3wuWfWS5EmhWNFXSE2U5eEoA6xqwFA9alpeV-ygP_7KJeErsDx4Fi7s8RgHO9n4xsuQMc53GgV1R_hS-DRgHE_b5fTO5_U3xS9lUduh3ke1NMgt-99UAXq7EceSUXC1BrSeWjUB9AZoUvqi7ZGS6dSZPCrr1OFeW5TEERQDceESISjvNQdn8r8H_YlQXwp6bRG8TQFXlMJSnJE4-VN",
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 32.6367027,
#                     "lng": -16.9463426
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 32.63802448029149,
#                         "lng": -16.9450930197085
#                     },
#                     "southwest": {
#                         "lat": 32.6353265197085,
#                         "lng": -16.9477909802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Golden Residence Hotel",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3447,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100027580733672682541\">Golden Residence Hotel</a>"
#                     ],
#                     "photo_reference": "Aap_uEDXzcj2W_3_a5LzV0qhzPfN5LaWwgQ6r9iIac_07bSjXAj9rNl5heKt36q8VK--cU2wzhslFHlQOk3sfW_MF33VfwtEB9QlWUOR9cvaJ392kIDRKlR0zadNIj_5s_UYiM6atylyZifFCssS8tbKu0fu92xB2JTjUrAl-7xsU3PoQowS",
#                     "width": 5171
#                 }
#             ],
#             "place_id": "ChIJQTNcTI9fYAwRFZ0_yhpNnKE",
#             "plus_code": {
#                 "compound_code": "J3P3+MF Funchal, Portugal",
#                 "global_code": "8C45J3P3+MF"
#             },
#             "rating": 4.5,
#             "reference": "ChIJQTNcTI9fYAwRFZ0_yhpNnKE",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 878,
#             "vicinity": "Rua do Cabrestante 25, Funchal"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 32.6380703,
#                     "lng": -16.9333924
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 32.6394710802915,
#                         "lng": -16.9320352197085
#                     },
#                     "southwest": {
#                         "lat": 32.6367731197085,
#                         "lng": -16.9347331802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Hotel Porto Mare",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 836,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/115203275421191744628\">Hotel Porto Mare</a>"
#                     ],
#                     "photo_reference": "Aap_uEBB5AA_SnhJI9Kq_elHGACoJU_tRvyyyV56OwIkLtCuTsuhFWgLEjP3gatYlTV5igf643Ojb7dlXOoPqQJbLpkcDRwqlN68jfoRBUJ-Oq1fZKVtdSfz0RMe-QGDSpm32LO3PhDjesxLuTrwUNFTOLjUhm2HkLrbV0kW03QAbvYfoXqS",
#                     "width": 1258
#                 }
#             ],
#             "place_id": "ChIJDxt5KQZgYAwR80VEUS_M1lM",
#             "plus_code": {
#                 "compound_code": "J3Q8+6J Funchal, Portugal",
#                 "global_code": "8C45J3Q8+6J"
#             },
#             "rating": 4.7,
#             "reference": "ChIJDxt5KQZgYAwR80VEUS_M1lM",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 872,
#             "vicinity": "Rua Simpl\u00edcio dos Passos Gouveia 21, Funchal"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 32.643756,
#                     "lng": -16.9172976
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 32.64516353029149,
#                         "lng": -16.9159692697085
#                     },
#                     "southwest": {
#                         "lat": 32.64246556970849,
#                         "lng": -16.9186672302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Pestana Casino Park",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2268,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100203406998265066688\">Nasrin Mohseni</a>"
#                     ],
#                     "photo_reference": "Aap_uEB7RLKWySwWjZFfbuz2pz5tvSfzbtcyG92fMXPfF2TjTFPBt4aHNrD7LgQOVMp7ot0fnYUKeKrIPaeOdTfer1wPuhBAhz5sz9dCMs-GSy61agHwPMHuL00rZNZq2wkURgHnn-mVDbMUHHL4snFF7R8FhA-wrZ9BpZxiszDbjVw-Qm2e",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJ2zjDbftfYAwRrOONXntExO0",
#             "plus_code": {
#                 "compound_code": "J3VM+G3 Funchal, Portugal",
#                 "global_code": "8C45J3VM+G3"
#             },
#             "rating": 4.4,
#             "reference": "ChIJ2zjDbftfYAwRrOONXntExO0",
#             "scope": "GOOGLE",
#             "types": [
#                 "spa",
#                 "lodging",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1780,
#             "vicinity": "Rua Imperatriz Dona Am\u00e9lia, Funchal"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 32.7192535,
#                     "lng": -17.1738148
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 32.72067468029149,
#                         "lng": -17.1724315197085
#                     },
#                     "southwest": {
#                         "lat": 32.7179767197085,
#                         "lng": -17.1751294802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Calheta Beach - All-inclusive",
#             "photos": [
#                 {
#                     "height": 1080,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/109371647589178483043\">Calheta Beach Resort</a>"
#                     ],
#                     "photo_reference": "Aap_uEAgU0-nZTVvE-yLzyd8jg6XZAOm4JMRqhb6CoBRBQ06SjQGjI11x69TjKiKynU1UvuRy9HimjCEYOYIKXEEhAq-geWXy__roCILXhjkCdDcSHLFjLJ4TcR0oYmLoUVYZFalLPTRdi2WdV44SdMUFEwHpplA5qbVZ_Al5MmcnKNG4S1K",
#                     "width": 1620
#                 }
#             ],
#             "place_id": "ChIJAQAAkH2xRwsRGOpDKlVW5NM",
#             "plus_code": {
#                 "compound_code": "PR9G+PF Estreito da Calheta, Portugal",
#                 "global_code": "8C44PR9G+PF"
#             },
#             "rating": 4.4,
#             "reference": "ChIJAQAAkH2xRwsRGOpDKlVW5NM",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 820,
#             "vicinity": "Avenida Dom Manuel I 3, Estreito da Calheta"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 32.6385263,
#                     "lng": -16.9326786
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 32.6397172302915,
#                         "lng": -16.9312685697085
#                     },
#                     "southwest": {
#                         "lat": 32.6370192697085,
#                         "lng": -16.9339665302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Muthu Raga Madeira Hotel",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1920,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114034828561641097287\">Muthu Raga Madeira Hotel</a>"
#                     ],
#                     "photo_reference": "Aap_uEAiLp-bYsYBVA5cDCQIpsnY1EWgztxuz1pgaNO12jHu_AEpeogkkc0sdh-aClSy2hsK0M3Lzu_I251740GIt3s2NlG-4bc9KtM-eh_P5K6duHDdwvmKXixFemHAMIH3ZKeiPJuSZPtk6-xrmnov59wO-Z3o3HewZI31SStqlCSthQmg",
#                     "width": 2880
#                 }
#             ],
#             "place_id": "ChIJK5NFgPNfYAwRkai3gfastBk",
#             "plus_code": {
#                 "compound_code": "J3Q8+CW Funchal, Portugal",
#                 "global_code": "8C45J3Q8+CW"
#             },
#             "rating": 3.8,
#             "reference": "ChIJK5NFgPNfYAwRkai3gfastBk",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1055,
#             "vicinity": "Estrada Monumental 302, Funchal"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 32.6477001,
#                     "lng": -16.913508
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 32.6489944802915,
#                         "lng": -16.9120166697085
#                     },
#                     "southwest": {
#                         "lat": 32.6462965197085,
#                         "lng": -16.9147146302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "The Vine Hotel",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3511,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106154104745669969961\">The Vine Hotel</a>"
#                     ],
#                     "photo_reference": "Aap_uEAF9r0UMz_aSKcBDx-8at6dY02XC0L10XddMhU5G7sNupytfOTX9sYtYYv4cpRvaEYBnh38blYuEkxsvhmWKOixRBr4NBELCNTIMCdc-uOHSgPCfyX52qus--c40xLPaKpvzBwiZsgSkR9NG6tsBdxS2UD4RRhomhYuEbRQMmolhvz3",
#                     "width": 4724
#                 }
#             ],
#             "place_id": "ChIJ_RxxrgdgYAwRI-IEfLidykc",
#             "plus_code": {
#                 "compound_code": "J3XP+3H Funchal, Portugal",
#                 "global_code": "8C45J3XP+3H"
#             },
#             "rating": 4.6,
#             "reference": "ChIJ_RxxrgdgYAwRI-IEfLidykc",
#             "scope": "GOOGLE",
#             "types": [
#                 "spa",
#                 "lodging",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 474,
#             "vicinity": "Rua dos Aranhas 27, Funchal"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 32.647023,
#                     "lng": -16.899996
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 32.6485149302915,
#                         "lng": -16.8985851697085
#                     },
#                     "southwest": {
#                         "lat": 32.64581696970851,
#                         "lng": -16.9012831302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Hotel Porto Santa Maria",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 5304,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106835877167861213887\">Hotel Porto Santa Maria</a>"
#                     ],
#                     "photo_reference": "Aap_uEAWLMkUvgFHMlqRmkLyFx-8OhXxZqoocPjWuDErVgO5dID56HxQQudwt8jCyttcFeYP9dPamx8eRKjsz-oaS7LdvHN4kpp0G46TUVqcRjfaboI0FlL5Wd93BLRLMgqu14AKxr16Y7ChKnRNiL2r-q7TDQCn_-RNejCI0PGCVBj0JqGL",
#                     "width": 7952
#                 }
#             ],
#             "place_id": "ChIJGRJXthpgYAwRjsevO8PTrYg",
#             "plus_code": {
#                 "compound_code": "J4W2+R2 Funchal, Portugal",
#                 "global_code": "8C45J4W2+R2"
#             },
#             "rating": 4.6,
#             "reference": "ChIJGRJXthpgYAwRjsevO8PTrYg",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 449,
#             "vicinity": "Avenida do Mar e das Comunidades Madeirenses, Funchal"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 32.64906300000001,
#                     "lng": -16.919015
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 32.65031713029151,
#                         "lng": -16.9175088697085
#                     },
#                     "southwest": {
#                         "lat": 32.64761916970851,
#                         "lng": -16.9202068302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Four Views Ba\u00eda",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2736,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/118415997057593903704\">Nuno Rodrigues</a>"
#                     ],
#                     "photo_reference": "Aap_uEAnUuOxbJi394KQgZYC7XavKEkWmxCSVKtK-KMVB_kknIfXj3fDi41FlMIfO63Wr6QhQWn1-uVeX0xL3WxMPYUxl4LW5mJvyTbbkc5ogU5-kM3hIJdpxWASEn1n4z9gClNd-mltsIWVf8o4nufj_YdkF8sQyDIrpfno1Keqcwi8xn3M",
#                     "width": 3648
#                 }
#             ],
#             "place_id": "ChIJMQNvZeRfYAwR3PvoI0idhTQ",
#             "plus_code": {
#                 "compound_code": "J3XJ+J9 Funchal, Portugal",
#                 "global_code": "8C45J3XJ+J9"
#             },
#             "rating": 4.4,
#             "reference": "ChIJMQNvZeRfYAwR3PvoI0idhTQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1577,
#             "vicinity": "Rua das Maravilhas 74, Funchal"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 32.6377412,
#                     "lng": -16.9339811
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 32.6390883802915,
#                         "lng": -16.9326507697085
#                     },
#                     "southwest": {
#                         "lat": 32.6363904197085,
#                         "lng": -16.9353487302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "name": "Il Massimo / Mare Nostrum Restaurante",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 1367,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100634441711966813380\">Il Massimo / Mare Nostrum Restaurante</a>"
#                     ],
#                     "photo_reference": "Aap_uEAA4mc5Ijh2uwST1E_0R4idF2BNQyHdaDCPaXl1WgT5hrFwO-mRZjfdrM88tAveilZtE8OmRDjOoWywlu9nNknu-fd1YlKRsOnJrDwrFPqjNUXQhX7Iv7U1Do3gr_R21BMWOjSOh-bUyTeF0dFfTO2AEVPkYCjNO_0SeO8XX4jG1v6A",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJu1JUn_RfYAwROz4IaZKM6Do",
#             "plus_code": {
#                 "compound_code": "J3Q8+3C Funchal, Portugal",
#                 "global_code": "8C45J3Q8+3C"
#             },
#             "price_level": 2,
#             "rating": 4.3,
#             "reference": "ChIJu1JUn_RfYAwROz4IaZKM6Do",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "parking",
#                 "spa",
#                 "lodging",
#                 "bar",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 133,
#             "vicinity": "Rua de Leichlingen 2 a 4, Funchal"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 32.63537809999999,
#                     "lng": -16.9408847
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 32.6367964302915,
#                         "lng": -16.9395546197085
#                     },
#                     "southwest": {
#                         "lat": 32.6340984697085,
#                         "lng": -16.9422525802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Madeira Regency Cliff",
#             "photos": [
#                 {
#                     "height": 3456,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110148507783795520165\">Thomas Engfer</a>"
#                     ],
#                     "photo_reference": "Aap_uECj3W_bnvrqU6Qj3myc5UqMtaJjTXIoOYmgLGUgdSVw5ykVUPVqDqHfQ1p6L0OggHj-Vkbcsb5VCaaen9AD7NJv6Q45RwpcHpdTtw0Wm_NsZGbBKfjkXh6l_62wrJjOvoOUiROa9QTw66jiqAU9nVTzJeRFqXC-_tccY0JC8_lnAe04",
#                     "width": 4608
#                 }
#             ],
#             "place_id": "ChIJIyrgcZtfYAwRqi6ZValFkB0",
#             "plus_code": {
#                 "compound_code": "J3P5+5J Funchal, Portugal",
#                 "global_code": "8C45J3P5+5J"
#             },
#             "rating": 4.6,
#             "reference": "ChIJIyrgcZtfYAwRqi6ZValFkB0",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 240,
#             "vicinity": "Travessa da Quinta Cala\u00e7a 6, Funchal"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 32.6503599,
#                     "lng": -16.8391952
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 32.65169118029149,
#                         "lng": -16.8378836697085
#                     },
#                     "southwest": {
#                         "lat": 32.6489932197085,
#                         "lng": -16.8405816302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Quinta Splendida Wellness & Botanical Garden",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2960,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/105607141481928456631\">Quinta Splendida Wellness &amp; Botanical Garden Hotel</a>"
#                     ],
#                     "photo_reference": "Aap_uECrDIxs099mvILRa1oUs5hTNgmoNETQuUMnUbVK-KHKkgB0lf9apIHT3C3pNhhiXNOPgEueTNZFpeodDttugD2OXxncXAA9m7BTxiS7OD4VGDN1y6SfB7j2d-LugzM1AZXZcFgwnyVGaQCkGbbbIE13taferF1t_xo1kVvPxCV6s97x",
#                     "width": 6016
#                 }
#             ],
#             "place_id": "ChIJT35tO-FhYAwRnn-qzDilTqg",
#             "plus_code": {
#                 "compound_code": "M526+48 Cani\u00e7o, Portugal",
#                 "global_code": "8C45M526+48"
#             },
#             "rating": 4.6,
#             "reference": "ChIJT35tO-FhYAwRnn-qzDilTqg",
#             "scope": "GOOGLE",
#             "types": [
#                 "spa",
#                 "lodging",
#                 "park",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 682,
#             "vicinity": "Estrada da Ponta Oliveira 11, Cani\u00e7o"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 32.6382724,
#                     "lng": -16.9314672
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 32.6395698302915,
#                         "lng": -16.9301193197085
#                     },
#                     "southwest": {
#                         "lat": 32.63687186970851,
#                         "lng": -16.93281728029151
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Four Views Monumental",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 6936,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/115994230390063679403\">Mena Sousa-Kamper</a>"
#                     ],
#                     "photo_reference": "Aap_uEDldtV4ntXC0QPstpN-IwysE_Lano3AOSl4mveuy5Wyn_IR5n1kQ87MyZFNx6W6sND8VTiJ4TcsGWgyXvzFsjqXEVDgFtcQnNQdf_PuqDNZqmu1rv4OONuj3kNFYyLjXo8nnm_Q4sJOOV72UD9hh1jp-K1OGr58ReRT_tvPMVCI7qF0",
#                     "width": 9248
#                 }
#             ],
#             "place_id": "ChIJSyEx9fNfYAwRxFR49Pw2ZgE",
#             "plus_code": {
#                 "compound_code": "J3Q9+8C Funchal, Portugal",
#                 "global_code": "8C45J3Q9+8C"
#             },
#             "rating": 4.4,
#             "reference": "ChIJSyEx9fNfYAwRxFR49Pw2ZgE",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1028,
#             "vicinity": "Estrada Monumental 284, Funchal"
#         },
#         {
#             "business_status": "CLOSED_TEMPORARILY",
#             "geometry": {
#                 "location": {
#                     "lat": 32.6432653,
#                     "lng": -16.8516565
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 32.6446469302915,
#                         "lng": -16.8502847197085
#                     },
#                     "southwest": {
#                         "lat": 32.6419489697085,
#                         "lng": -16.8529826802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Dom Pedro Garajau, Apartment Hotel & Nature",
#             "permanently_closed": true,
#             "photos": [
#                 {
#                     "height": 2160,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/118259146431246816180\">Dom Pedro Garajau, Apartment Hotel &amp; Nature</a>"
#                     ],
#                     "photo_reference": "Aap_uEADjTlgGA1EAAt-kdNw3ndYHOuDIKzFrvjVxStJBumGVQneb-q9SHSDRapcXq_3DLvM5QHuTGBrTgySoz6nZcU3il_ocqi1lwP1nzzbctcuBgusp42sVF4XJ-BsPb-2e4gd7plzNKJkeyRMTLOxg6z0QLimVu7lHAofMy4OVlCzQdPk",
#                     "width": 2880
#                 }
#             ],
#             "place_id": "ChIJf3pL3XeKYAwRXtsvzwov7rs",
#             "plus_code": {
#                 "compound_code": "J4VX+88 Cani\u00e7o, Portugal",
#                 "global_code": "8C45J4VX+88"
#             },
#             "rating": 3.6,
#             "reference": "ChIJf3pL3XeKYAwRXtsvzwov7rs",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 307,
#             "vicinity": "Estrada do Garajau 131, Cani\u00e7o"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 32.6364013,
#                     "lng": -16.939896
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 32.6377741802915,
#                         "lng": -16.9386480197085
#                     },
#                     "southwest": {
#                         "lat": 32.6350762197085,
#                         "lng": -16.9413459802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Hotel Ba\u00eda Azul",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2252,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/102613517848759582194\">Pete Jones</a>"
#                     ],
#                     "photo_reference": "Aap_uECNbDH9PzG1Qetj-qnt_pDbYi0Oxi-jzuwxRKz5MR9p7tpSpPEJ2zPuopQLE8MdC2yy9cDkbO8a11ubdqlosFkkIuMBpPI8qQmlfFIcCLt3EnTdJmu3j_tTJe0l7-KE2_iWYZ61YunX-eCBquJbaDmw9aoEM0Ql39NRJdljExr5WmhK",
#                     "width": 4000
#                 }
#             ],
#             "place_id": "ChIJgyjfrYxfYAwRY2pVU5jX5wM",
#             "plus_code": {
#                 "compound_code": "J3P6+H2 Funchal, Portugal",
#                 "global_code": "8C45J3P6+H2"
#             },
#             "rating": 4.6,
#             "reference": "ChIJgyjfrYxfYAwRY2pVU5jX5wM",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1191,
#             "vicinity": "Rua da Quinta Cala\u00e7a 1, Funchal"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 32.7524163,
#                     "lng": -17.2165414
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 32.7536441302915,
#                         "lng": -17.2152845197085
#                     },
#                     "southwest": {
#                         "lat": 32.7509461697085,
#                         "lng": -17.2179824802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Hotel Jardim Atlantico",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107576124956230450208\">Donatas Dark\u0161as</a>"
#                     ],
#                     "photo_reference": "Aap_uEBaCpQQeg7gQzkIcJMRsS_vy-KNKjzGhsKcnXNivk_AvHXBWAjoustx_Zoyi7TjknjkmdGZbtKIJPmFUx0ziGImnLQnvOfOUOscRQvIuUXUPhANlCUsh0zJU7oxmYSXnYvGQnuDGr7c-J2vYG_Tkb0kRL49UTHpbgsvpQQs1a-i1sNk",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJNbbLYhNSYAwRasgeiYHxWIA",
#             "plus_code": {
#                 "compound_code": "QQ2M+X9 Prazeres, Portugal",
#                 "global_code": "8C44QQ2M+X9"
#             },
#             "rating": 4.4,
#             "reference": "ChIJNbbLYhNSYAwRasgeiYHxWIA",
#             "scope": "GOOGLE",
#             "types": [
#                 "spa",
#                 "lodging",
#                 "bar",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 339,
#             "vicinity": "Caminho Lombo da Rocha 1, Prazeres"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 32.63832469999999,
#                     "lng": -16.9307499
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 32.6395993802915,
#                         "lng": -16.9293978197085
#                     },
#                     "southwest": {
#                         "lat": 32.6369014197085,
#                         "lng": -16.9320957802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Vila Baleira Funchal",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1365,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/105616766120386285166\">Vila Baleira Funchal</a>"
#                     ],
#                     "photo_reference": "Aap_uEBq5phS8vET182CQFfdEGjh4vU6NXmWmtf02cnN8OD_ldgma06o31993hMGLypchrZ3sLMNH-zCdJRX84QvjfDCI1uz0Lz-jdJ0-BExjZWKMPbaVkJW8Pv6e5BWGLjtq0l13ysxvgl836kjOZIgsyRyVmKFPwezyl0-JRTLCCmRnyHk",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJlQDKKvFfYAwRiVjBcJcdshU",
#             "plus_code": {
#                 "compound_code": "J3Q9+8P Funchal, Portugal",
#                 "global_code": "8C45J3Q9+8P"
#             },
#             "rating": 4.1,
#             "reference": "ChIJlQDKKvFfYAwRiVjBcJcdshU",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 614,
#             "vicinity": "Estrada Monumental 274, Funchal"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 32.6516323,
#                     "lng": -16.9094845
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 32.65295173029149,
#                         "lng": -16.9081043697085
#                     },
#                     "southwest": {
#                         "lat": 32.65025376970849,
#                         "lng": -16.9108023302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Hotel Orqu\u00eddea",
#             "photos": [
#                 {
#                     "height": 2322,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100908967382097268463\">Wilfried Sperber</a>"
#                     ],
#                     "photo_reference": "Aap_uEACoLfI70-vqsHkqJGEzehM6ZqpXsWVCjs2BDHiyYNKKBbipvM2zm6skIhPU1BZtikAiwl2JEJ_XsbRfrIlFhLNd5rfp1CQeFlG1g3-ojyAVFHmzDWsbFxUwv-PbOqHUlEqaA3pw3_W6EjFQlGcnxpEj96QWrCj17uZHJ3LJ70gCsQ5",
#                     "width": 4128
#                 }
#             ],
#             "place_id": "ChIJp0yOnAlgYAwRFpZ2G6PTeh0",
#             "plus_code": {
#                 "compound_code": "M32R+M6 Funchal, Portugal",
#                 "global_code": "8C45M32R+M6"
#             },
#             "rating": 4,
#             "reference": "ChIJp0yOnAlgYAwRFpZ2G6PTeh0",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 446,
#             "vicinity": "Rua dos Netos 69 71, Funchal"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 32.6466529,
#                     "lng": -16.8274639
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 32.6480024302915,
#                         "lng": -16.8261159197085
#                     },
#                     "southwest": {
#                         "lat": 32.6453044697085,
#                         "lng": -16.8288138802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Four Views Oasis",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1127,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/109430983223651994260\">Four Views Oasis</a>"
#                     ],
#                     "photo_reference": "Aap_uEDqgaOEX_4fKGrofKqP6GqhpfOjK5j_9T2pu0w6VqYqCgA_qGp6MDa-WrXNpfSCXchIHgYjexv_THliK4Z3ep7V_R0dmKRovkbflWGeuUWToIQgwgXKOfAEj1-A3Z6RZ-B2Bpajpg0xkKK_o9rIxJErK2BH1VHs9s6gT1JzKI253NNf",
#                     "width": 1920
#                 }
#             ],
#             "place_id": "ChIJS3rkbQeKYAwRreaiSk6Y6IU",
#             "plus_code": {
#                 "compound_code": "J5WF+M2 Cani\u00e7o, Portugal",
#                 "global_code": "8C45J5WF+M2"
#             },
#             "rating": 4.4,
#             "reference": "ChIJS3rkbQeKYAwRreaiSk6Y6IU",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1127,
#             "vicinity": "Praia Dos Reis Magos, Cani\u00e7o"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 32.6478606,
#                     "lng": -16.9200769
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 32.6492241802915,
#                         "lng": -16.91878781970849
#                     },
#                     "southwest": {
#                         "lat": 32.64652621970851,
#                         "lng": -16.9214857802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Quintinha S\u00e3o Jo\u00e3o Hotel & Spa",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 853,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/113623046374992212352\">Quintinha S\u00e3o Jo\u00e3o Hotel &amp; Spa</a>"
#                     ],
#                     "photo_reference": "Aap_uEATxLkKr-pTgbWGWOn0EjuLCghMw-9_Dz9J9m8ydBHHNjfEvprDGNZ8mOsx7u3o53Lwe0wSnUgJFBCOjxPoCNOUb51krBHO-8wMyXw1B7YHBDlI0PlWWUoUBHMsgceGu49ExjiCXHC4IEMtJBu_61oWheQ7okfCZwgh55MlkFEpCPox",
#                     "width": 1280
#                 }
#             ],
#             "place_id": "ChIJkXOXWORfYAwR4oDEL17zjeA",
#             "plus_code": {
#                 "compound_code": "J3XH+4X Funchal, Portugal",
#                 "global_code": "8C45J3XH+4X"
#             },
#             "rating": 4.7,
#             "reference": "ChIJkXOXWORfYAwR4oDEL17zjeA",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 234,
#             "vicinity": "Levada de S\u00e3o Jo\u00e3o 4, Funchal"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 32.6408542,
#                     "lng": -16.9239481
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 32.6422150802915,
#                         "lng": -16.9226708697085
#                     },
#                     "southwest": {
#                         "lat": 32.6395171197085,
#                         "lng": -16.9253688302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Reid's Palace, A Belmond Hotel, Madeira",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106499928766004037946\">Morad El Amrati</a>"
#                     ],
#                     "photo_reference": "Aap_uEAmff71snUfX9FsVOLSnyEnckzbAHpyRxEO8b82hcSF1Df2UVFypwzlY24uUdAS2sAvzp-BEjzwMiUufNkD1FPirRKX6bF5wwWpCqfpfzpPmyPNIi1OFpWIkyLqZHJMLq4w6uEzww9x-khzjvSHQquuc8C1Rz3LRIv6SOqiNZdZIuYc",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJFXOVoPBfYAwRJ5wDs8h_jHc",
#             "plus_code": {
#                 "compound_code": "J3RG+8C Funchal, Portugal",
#                 "global_code": "8C45J3RG+8C"
#             },
#             "rating": 4.7,
#             "reference": "ChIJFXOVoPBfYAwRJ5wDs8h_jHc",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1116,
#             "vicinity": "Estrada Monumental 139, Funchal"
#         }
#     ],
#     "status": "OK"
# }
# {
#     "html_attributions": [],
#     "next_page_token": "Aap_uEAaUWguF6ztUT6Gpr2R5Cu11O4HpTWLthftFAc-9dKQdJ1oLsooX960S_PTL3Cq09b4Pnvp74cQ0XDg9l7-AuesGCZAlct69yb5-tC70TTNBbcw9MTSLwdad0HaYAZOpLycbElYNHZQ5YSbBCDLOLalORPG7R7fNIGf8g4iYj4jthzP8bqjeDjvlp95gv9D-Bp9ON0sT3cO1MCLmsjnH2AyeTxfUO8FgtdvTRyAvR7P-VlLBx4h7FNiWuyKy7vqnSUWnySTmNP2Aj7Dr3Bp0c62HgOaBwB9zdVDswWD_DlqAoPJD-gTHg9rMjBGS3q42-r0RiL3mQBk59-SYb5-FDHxHyt6xRiPuZj41DAz76iGMQYZNH_z2PxOF9FVkP7EAHAzemQKvqnTzV5JSfPWTvpuGflH3nqBKc_T8Wdk0YVkBT7dGwmSrXcf",
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 44.4505398,
#                     "lng": -89.523983
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 44.4519415802915,
#                         "lng": -89.5223468697085
#                     },
#                     "southwest": {
#                         "lat": 44.4492436197085,
#                         "lng": -89.5250448302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Hampton Inn Plover-Stevens Point",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3000,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106590256782105386615\">Hampton Inn Plover-Stevens Point</a>"
#                     ],
#                     "photo_reference": "Aap_uECZvFR30qwgJgJU9Se4KtXDVhYTrr6xxQQ6b6IU71bvRJU4dyg4W_qbJYcngn1yMgWsLhGcexDcJvv-CH3yYIxTUonrOZqgb5TnwLaWygrbPHFtrcksuPwX1SO3gxL-5QuicM62K9Dy9zQVVxZ_EPV7dCoStS6AF3L0of1-G8QkhfT7",
#                     "width": 4494
#                 }
#             ],
#             "place_id": "ChIJ4z8ALBdXAIgRs8pH_MjXCBA",
#             "plus_code": {
#                 "compound_code": "FF2G+6C Plover, WI, USA",
#                 "global_code": "86PGFF2G+6C"
#             },
#             "rating": 4.5,
#             "reference": "ChIJ4z8ALBdXAIgRs8pH_MjXCBA",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 251,
#             "vicinity": "3090 Village Park Drive, Plover"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 44.5221232,
#                     "lng": -89.52336609999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 44.52356033029149,
#                         "lng": -89.5220060197085
#                     },
#                     "southwest": {
#                         "lat": 44.5208623697085,
#                         "lng": -89.5247039802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Fairfield Inn & Suites by Marriott Stevens Point",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1366,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/115737108956952347413\">Fairfield Inn &amp; Suites by Marriott Stevens Point</a>"
#                     ],
#                     "photo_reference": "Aap_uEDZtIizu_RydkEY6vZfOoFvS4Ds8ylTGyRsHAhSwOivA6_iCq_h981OiuAGetLkLR8tfBq0d6hpiYzBe0faHO3XQ5dAIV30J6kRS423-QIGJ2iEo9IkiilOaRPT-1dQ6kXq5s8xqqocYibOQGmN8_4IgwVJ9SiN0R04xR1LeXRgQw0v",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJLRfKGEVQAIgRDi_59pk7Z74",
#             "plus_code": {
#                 "compound_code": "GFCG+RM Stevens Point, WI, USA",
#                 "global_code": "86PGGFCG+RM"
#             },
#             "rating": 4.3,
#             "reference": "ChIJLRfKGEVQAIgRDi_59pk7Z74",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 218,
#             "vicinity": "5317 U.S. 10 East, Stevens Point"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 44.525923,
#                     "lng": -89.50441000000001
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 44.5266560802915,
#                         "lng": -89.50360220000002
#                     },
#                     "southwest": {
#                         "lat": 44.5239581197085,
#                         "lng": -89.50683339999999
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Holiday Inn Stevens Point - Convention Ctr, an IHG Hotel",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1868,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107141765245605672253\">Ryan Harden</a>"
#                     ],
#                     "photo_reference": "Aap_uECV1gAtFCaXkpKPBPdtAbTTk6FYv_oFTJC_0JjNaZu1oICWg3TBxPYNK3-nPMQrUaoKKrS2-VtVGrlksfVdJpvAw7qRkBoJ6cAbu3XhrOMCAnGyv0gj0uANJgVJ42CI8Uuu0DlgBru8JrLpY1TTaY98y8NQ5rupTwwh0mORiVXqnSGx",
#                     "width": 4000
#                 }
#             ],
#             "place_id": "ChIJu87IP7FRAIgRuAh48U7JpXU",
#             "plus_code": {
#                 "compound_code": "GFGW+96 Stevens Point, WI, USA",
#                 "global_code": "86PGGFGW+96"
#             },
#             "rating": 4.2,
#             "reference": "ChIJu87IP7FRAIgRuAh48U7JpXU",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 941,
#             "vicinity": "1001 Amber Avenue, Stevens Point"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 44.86631670000001,
#                     "lng": -89.6382611
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 44.86802868029149,
#                         "lng": -89.6368475197085
#                     },
#                     "southwest": {
#                         "lat": 44.8653307197085,
#                         "lng": -89.6395454802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Stoney Creek Hotel Wausau - Rothschild",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3701,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103706032211941735400\">Stoney Creek Hotel Wausau - Rothschild</a>"
#                     ],
#                     "photo_reference": "Aap_uEAZk8RrXoSi0pMs2lXLIOsBlbRRYb9Bya-0-2JSoa-0iZPbl0ZEGhgDiFv7slMJF15KGiT6QJdiBE2X6xZMaBAyhIukV3ANatQ3Z7q85_BizMjWQRlrfRDhu-mhIhM2nu6ocddFwjghKfs1RFzuQV23-LzL67Sk1zneDmBW-KhHsx27",
#                     "width": 5546
#                 }
#             ],
#             "place_id": "ChIJcZgkNEIjAIgRcFEk_vou0F0",
#             "plus_code": {
#                 "compound_code": "V986+GM Rothschild, WI, USA",
#                 "global_code": "86PGV986+GM"
#             },
#             "rating": 4.4,
#             "reference": "ChIJcZgkNEIjAIgRcFEk_vou0F0",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 544,
#             "vicinity": "1100 Imperial Avenue, Rothschild"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
# ...
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "Brazil"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -17.5167101,
#                     "lng": -49.4436691
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -17.5153611197085,
#                         "lng": -49.4423200197085
#                     },
#                     "southwest": {
#                         "lat": -17.5180590802915,
#                         "lng": -49.4450179802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Fique Bonita",
#             "place_id": "ChIJy5lfZzKBX5MRvwxXBdpq7F4",
#             "plus_code": {
#                 "compound_code": "FHM4+8G Pontalina - State of Goi\u00e1s, Brazil",
#                 "global_code": "58JGFHM4+8G"
#             },
#             "reference": "ChIJy5lfZzKBX5MRvwxXBdpq7F4",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Avenida A, Pontalina"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -17.5179208,
#                     "lng": -49.45674349999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -17.5164977697085,
#                         "lng": -49.4554074697085
#                     },
#                     "southwest": {
#                         "lat": -17.5191957302915,
#                         "lng": -49.4581054302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Calda Novo Hotel de Roma",
#             "place_id": "ChIJRXZaeQqHX5MRp3ActsRh6FI",
#             "plus_code": {
#                 "compound_code": "FGJV+R8 Pontalina - State of Goi\u00e1s, Brazil",
#                 "global_code": "58JGFGJV+R8"
#             },
#             "reference": "ChIJRXZaeQqHX5MRp3ActsRh6FI",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Pontalina"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -17.51527399999999,
#                     "lng": -49.4403076
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -17.5140279197085,
#                         "lng": -49.4389440697085
#                     },
#                     "southwest": {
#                         "lat": -17.5167258802915,
#                         "lng": -49.4416420302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "HOTEL BOA VISTA",
#             "place_id": "ChIJ7dVAcICBX5MROff80VuQKKM",
#             "plus_code": {
#                 "compound_code": "FHM5+VV Pontalina - State of Goi\u00e1s, Brazil",
#                 "global_code": "58JGFHM5+VV"
#             },
#             "rating": 4.6,
#             "reference": "ChIJ7dVAcICBX5MROff80VuQKKM",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 5,
#             "vicinity": "AVENIDA E NUMERO, 147 - VILA BRASIL, Pontalina"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -17.5113529,
#                     "lng": -49.4532767
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -17.5100052197085,
#                         "lng": -49.4519635197085
#                     },
#                     "southwest": {
#                         "lat": -17.5127031802915,
#                         "lng": -49.4546614802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Recanto das Araras",
#             "place_id": "ChIJ-6s1RCmHX5MR2VGKyoI6cEk",
#             "plus_code": {
#                 "compound_code": "FGQW+FM Pontalina - State of Goi\u00e1s, Brazil",
#                 "global_code": "58JGFGQW+FM"
#             },
#             "reference": "ChIJ-6s1RCmHX5MR2VGKyoI6cEk",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Rua Alameda dos Buritis, 51-1, Pontalina"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -17.509786,
#                     "lng": -49.44303999999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -17.5084460697085,
#                         "lng": -49.4417362197085
#                     },
#                     "southwest": {
#                         "lat": -17.5111440302915,
#                         "lng": -49.4444341802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Recanto dos Para\u00edbas",
#             "place_id": "ChIJDa5npWSBX5MRCYPQ0zJVSIA",
#             "plus_code": {
#                 "compound_code": "FHR4+3Q Pontalina - State of Goi\u00e1s, Brazil",
#                 "global_code": "58JGFHR4+3Q"
#             },
#             "reference": "ChIJDa5npWSBX5MRCYPQ0zJVSIA",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Avenida D, 8812, Pontalina"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -17.533058,
#                     "lng": -49.4631737
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -17.53114745,
#                         "lng": -49.4596742
#                     },
#                     "southwest": {
#                         "lat": -17.53878965000001,
#                         "lng": -49.4643402
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Fazenda Sao Lorenco",
#             "photos": [
#                 {
#                     "height": 2322,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114465731421941877423\">Weber Martins</a>"
#                     ],
#                     "photo_reference": "Aap_uEChC15LY4Q1XPn7EIT7j9Zkf9wiFmBxpN3iUXs_otULbhp1i0U1jTYx2t855PsUx3q57ZGX6MdNO2mmUdHcdmcowtJG8i4aUzmaf6ko6h0eThMcTN3tV2VTW-FME6QXMV4Odmkw7giykClyhP5CmAHTkivV6m0_vodHOoPWfqfOfsUM",
#                     "width": 4128
#                 }
#             ],
#             "place_id": "ChIJJ3HDlyCHX5MRIB1oHci7kMY",
#             "plus_code": {
#                 "compound_code": "FG8P+QP Pontalina - State of Goi\u00e1s, Brazil",
#                 "global_code": "58JGFG8P+QP"
#             },
#             "rating": 5,
#             "reference": "ChIJJ3HDlyCHX5MRIB1oHci7kMY",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "Pontalina"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -17.6725643,
#                     "lng": -49.4139219
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -17.6711088697085,
#                         "lng": -49.4126447697085
#                     },
#                     "southwest": {
#                         "lat": -17.6738068302915,
#                         "lng": -49.41534273029149
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Fazenda Catirino",
#             "photos": [
#                 {
#                     "height": 768,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/113323120828030002064\">M\u00e1rio Henrique In\u00e1cio de Paula</a>"
#                     ],
#                     "photo_reference": "Aap_uEAqkoMsGt96mktAEmp7wkg5ftYGZbX_yjKftMy6Cv4sEjmGVhHdej2FOEmjONBHSadfgqvuXGwrg8Ql7Ha4fH_Ao2rjrRHh2RmKmTyo-J_WOSqU9s8fn98oP2PVFnncHAszZziXHea0w2nV3fM6U7F8VPvf2yHTJlf8x7OevnSZy8_-",
#                     "width": 1024
#                 }
#             ],
#             "place_id": "ChIJGQJWq-F9oJQRSdIv23EDA3o",
#             "plus_code": {
#                 "compound_code": "8HGP+XC Alo\u00e2ndia - State of Goi\u00e1s, Brazil",
#                 "global_code": "58JG8HGP+XC"
#             },
#             "reference": "ChIJGQJWq-F9oJQRSdIv23EDA3o",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Unnamed Road, Alo\u00e2ndia"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -17.44493,
#                     "lng": -49.640277
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -17.44398174999999,
#                         "lng": -49.63854500000001
#                     },
#                     "southwest": {
#                         "lat": -17.44777475,
#                         "lng": -49.645473
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Fazenda Varzea da Alegria",
#             "place_id": "ChIJmTgD0UOTX5MRDWotuUdJWkY",
#             "plus_code": {
#                 "compound_code": "H945+2V Edealina - State of Goi\u00e1s, Brazil",
#                 "global_code": "58JGH945+2V"
#             },
#             "rating": 5,
#             "reference": "ChIJmTgD0UOTX5MRDWotuUdJWkY",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 3,
#             "vicinity": "Edealina"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -17.7321353,
#                     "lng": -49.4776196
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -17.7308056197085,
#                         "lng": -49.47630346970851
#                     },
#                     "southwest": {
#                         "lat": -17.7335035802915,
#                         "lng": -49.4790014302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "HOTEL E POUSADA ITAMBE",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "place_id": "ChIJL60ee9JkoJQR1vn9-7s4NIQ",
#             "plus_code": {
#                 "compound_code": "7G9C+4X Setor Central, Alo\u00e2ndia - GO, Brazil",
#                 "global_code": "58JG7G9C+4X"
#             },
#             "rating": 4.1,
#             "reference": "ChIJL60ee9JkoJQR1vn9-7s4NIQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 8,
#             "vicinity": "Avenida 11 de Novembro, 266-392 - Setor Central, Alo\u00e2ndia"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -17.4257407,
#                     "lng": -49.6608483
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -17.4243321197085,
#                         "lng": -49.6594869697085
#                     },
#                     "southwest": {
#                         "lat": -17.4270300802915,
#                         "lng": -49.6621849302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Hotel Santo Ant\u00f4nio",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 554,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103266570388692751393\">Hotel Santo Ant\u00f4nio</a>"
#                     ],
#                     "photo_reference": "Aap_uECYhVwSjVxu_qmhPjNRMMIIJdKorC7wgxAPkyBNnpyCBZr5QPvA608HEg6OVrCa6elLEDKCZr0cHtAO_WblT-SECxxjRz8iKDoGjU_Jh_dEEVOxS_iXtgnXL-gUcLsAWq0P7LQE1NK19BEFxi3KMy-AgK8YLc2iHTPOWiHQRf665ixb",
#                     "width": 1280
#                 }
#             ],
#             "place_id": "ChIJdxTlMhyTX5MRAaOSwlAfmu8",
#             "plus_code": {
#                 "compound_code": "H8FQ+PM Edealina - State of Goi\u00e1s, Brazil",
#                 "global_code": "58JGH8FQ+PM"
#             },
#             "rating": 4.4,
#             "reference": "ChIJdxTlMhyTX5MRAaOSwlAfmu8",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 98,
#             "vicinity": "Rua Vinte e Um, 1332 - Centro, Edealina"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -17.42444339999999,
#                     "lng": -49.6676075
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -17.4231269197085,
#                         "lng": -49.6662648197085
#                     },
#                     "southwest": {
#                         "lat": -17.4258248802915,
#                         "lng": -49.6689627802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Hotel Mundial",
#             "place_id": "ChIJVyRz5R6TX5MRzNC2ReW7kw0",
#             "plus_code": {
#                 "compound_code": "H8GJ+6X Edealina - State of Goi\u00e1s, Brazil",
#                 "global_code": "58JGH8GJ+6X"
#             },
#             "rating": 5,
#             "reference": "ChIJVyRz5R6TX5MRzNC2ReW7kw0",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 2,
#             "vicinity": "Brazil"
#         }
#     ],
#     "status": "OK"
# }
