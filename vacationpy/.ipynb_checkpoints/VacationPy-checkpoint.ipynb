# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json
# Import API key
from api_keys import g_key

# %%
# Load csv
path = os.path.join('..', 'weatherpy', 'weatherdata.csv' ) 
df = pd.read_csv(path)
df.head()
# Out:
#    Unnamed: 0       Cities Country  Temp (F)  Latitude  Longitude  \
# 0           0      sechura      PE     72.12   -5.5569   -80.8222
# 1           1  port alfred      ZA     60.46  -33.5906    26.8910
# 2           2      ushuaia      AR     37.02  -54.8000   -68.3000
# 3           3       barrow      US     39.22   71.2906  -156.7887
# 4           4      bubaque      GW     82.69   11.2833   -15.8333
#
#    Cloudiness (%)  Humidity (%)  Wind Speed (mph)        Date
# 0               1            64              6.22  1626797831
# 1              95            78             18.88  1626797603
# 2              75            69              4.61  1626797719
# 3              90            93             19.57  1626797775
# 4              19            75             10.60  1626797834

# %%
# Get rid of duplicate index column
df = df.drop(columns='Unnamed: 0')

# %%
# configure gmaps
gmaps.configure(api_key=g_key)

coords = df[(['Latitude', 'Longitude'])]

# %%
# Customize the size of the figure
figure_layout = {
    'width': '400px',
    'height': '300px',
    'border': '1px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto'
}
fig = gmaps.figure(layout=figure_layout)

# Add the layer to the map
fig.add_layer(gmaps.heatmap_layer(coords,df['Humidity (%)']))

#fig.add_layer(gmaps.heatmap_layer(coords, weights=df['Humidity (%)']))
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='300px', margin='0 auto 0 auto', padding='1px', wi…

# %%
# Drop any rows that contain missing values
df_ideal = df.dropna()
# Limit max temp values, cloudiness values, and wind speed values for ideal vacation spots
df_ideal = df_ideal.loc[(df_ideal['Temp (F)'] <= 83.0) & (df_ideal['Temp (F)'] > 77.0)
                       & (df_ideal['Cloudiness (%)'] < 15) & (df_ideal['Wind Speed (mph)'] < 10.0) & 
                       (df_ideal['Wind Speed (mph)'] > 4.0)]
df_ideal
# Out:
#          Cities Country  Temp (F)  Latitude  Longitude  Cloudiness (%)  \
# 303      chaves      US     82.58   33.3834  -104.4505               1
# 437     ipameri      BR     82.27  -17.7219   -48.1597               1
# 450  livingston      GB     78.87   55.9029    -3.5226               0
# 482     ondjiva      AO     80.64  -17.0667    15.7333               0
# 490   pontalina      BR     82.74  -17.5250   -49.4472               2
#
#      Humidity (%)  Wind Speed (mph)        Date
# 303            65              9.22  1626798058
# 437            13              4.56  1626798162
# 450            74              9.22  1626798102
# 482            19              4.61  1626798201
# 490            10              4.52  1626798207

# %%
hotel_df = df_ideal.copy()
hotel_df['Hotel Name'] = 'PlaceHolder'

# Loop through ideal cities
for city in hotel_df['Cities']:
    # get coordinates in needed format
    lat1 = (hotel_df.loc[(hotel_df['Cities'] == city)]['Latitude']).astype(str)
    lon1 = (hotel_df.loc[(hotel_df['Cities'] == city)]['Longitude']).astype(str)
    loc = lat1 + ", " + lon1
    # set up a parameters dictionary
    params = {
    'location': loc,
    #"location": hotel_df[(['Latitude', 'Longitude'])],
    "radius": 5000,
    "type": "lodging",
    "key": g_key
    }
    # base url
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # run a request using our params dictionary
    response = requests.get(base_url, params=params)
    
    # convert response to json
    places_data = response.json()

    # hotel name, city, country appended to lists

#Print the json (pretty printed) for last city to get structure idea
print(json.dumps(places_data, indent=4, sort_keys=True))
# Out:
# --------------------------------chaves-----------------------------------------
# {
#     "html_attributions": [],
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 33.3940282,
#                     "lng": -104.4820172
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 33.3954780802915,
#                         "lng": -104.4806682197085
#                     },
#                     "southwest": {
#                         "lat": 33.3927801197085,
#                         "lng": -104.4833661802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Red Barn RV Park",
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/105487762804475579207\">Jodi Miller</a>"
#                     ],
#                     "photo_reference": "Aap_uECN7GOka6SJwgYkYKhJg85VJt8zixBX8v_HDtMPzxYfze3eAobzPtaYwFJvRMi-12-F77JHRYt4CBzy3tNgkKsi6NCfDy1sM1GEJf1kX-upb25NIWHUipWpndIwtrxlmmyZLf7p3icO5EAfuXo5RcI9lIHrXfowkxsrblQKA_GsJh63",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJr4l9xVFv4oYRtK4NR_JezVs",
#             "plus_code": {
#                 "compound_code": "9GV9+J5 Roswell, NM, USA",
#                 "global_code": "855Q9GV9+J5"
#             },
#             "rating": 4.7,
#             "reference": "ChIJr4l9xVFv4oYRtK4NR_JezVs",
#             "scope": "GOOGLE",
#             "types": [
#                 "rv_park",
#                 "campground",
#                 "lodging",
#                 "park",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 259,
#             "vicinity": "2806 East 2nd Street, Roswell"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 33.3926697,
#                     "lng": -104.4982412
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 33.3949452,
#                         "lng": -104.4968988197085
#                     },
#                     "southwest": {
#                         "lat": 33.3919112,
#                         "lng": -104.4995967802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Trailer Village RV Park",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1365,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/117512419329014366007\">Trailer Village RV Park</a>"
#                     ],
#                     "photo_reference": "Aap_uEAm1nbJyqZOyeMPu_KqZ3OsHAkc9SIbhRABhldXe0CEaLSe4MybPYMxantTn2-9eo21JTV6q9z1vAwiCxGCKktJ30hrwrD7LAeGcqaw6nemusMIAJSxvKsabARMqWrFfEm5oc9qvWWCnW0WP5OnfcObPRIGlyl7O--4ckLZN3shfAhG",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJRYy3Czdv4oYR_DLJ72Q1MhQ",
#             "plus_code": {
#                 "compound_code": "9GV2+3P Roswell, NM, USA",
#                 "global_code": "855Q9GV2+3P"
#             },
#             "rating": 4.6,
#             "reference": "ChIJRYy3Czdv4oYR_DLJ72Q1MhQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "rv_park",
#                 "campground",
#                 "lodging",
#                 "park",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 400,
#             "vicinity": "1706 East 2nd Street, Roswell"
#         }
#     ],
#     "status": "OK"
# }
# --------------------------------ipameri-----------------------------------------
# {
#     "html_attributions": [],
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -17.7160452,
#                     "lng": -48.1623751
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -17.7146670697085,
#                         "lng": -48.16108226970849
#                     },
#                     "southwest": {
#                         "lat": -17.7173650302915,
#                         "lng": -48.16378023029149
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Real Hotel",
#             "photos": [
#                 {
#                     "height": 2128,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106077519280644385316\">Idu Ferreira</a>"
#                     ],
#                     "photo_reference": "Aap_uEAo_unGTmHLle-nxKQndboX-BY1Iq8XQZRolgjJVGIlmg9YY3pugBHkwm0z6WPJRTAcr1XFmFNLmXS1yyoErE-5Q7TbtTW9OPHn2bIjmcIU0ORhXVXMeYUkws4LWCLVhD1w9lSmWTb5JTxDZRbmEZIPAl9qkLuPsUVe2_4hv1IbINIW",
#                     "width": 4608
#                 }
#             ],
#             "place_id": "ChIJxfDQd-EFp5QRO_Jcqx1u3D0",
#             "plus_code": {
#                 "compound_code": "7RMQ+H2 Dom Vital, Ipameri - GO, Brazil",
#                 "global_code": "58JH7RMQ+H2"
#             },
#             "rating": 3.5,
#             "reference": "ChIJxfDQd-EFp5QRO_Jcqx1u3D0",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 179,
#             "vicinity": "Rua Intendente Jos\u00e9 Bernardino da Costa, 2 - Dom Vital, Ipameri"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -17.7213998,
#                     "lng": -48.1620126
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -17.7201194197085,
#                         "lng": -48.16070491970849
#                     },
#                     "southwest": {
#                         "lat": -17.7228173802915,
#                         "lng": -48.16340288029149
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Tabajara Hotel",
#             "photos": [
#                 {
#                     "height": 4128,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/117114364849881687858\">wanderson de sa</a>"
#                     ],
#                     "photo_reference": "Aap_uEA405M4bLo25YV2loM45OkkUBbzY_cxyleYdxUAUz_fXElfK-2yj5qhCLxRdB3tFJamTKE1mBF9cbOYdGTkdsjQYQhabeSc6ByR7C2HtwbcjQLZGi-lpcGxsV-JrKXLL4faoRD24G2V70foHoEjCPmC0txkuxl8DfUSMQjI0U9SRktx",
#                     "width": 2322
#                 }
#             ],
#             "place_id": "ChIJKRi9fOAFp5QRbrdBK8vcntA",
#             "plus_code": {
#                 "compound_code": "7RHQ+C5 Centro, Ipameri - GO, Brazil",
#                 "global_code": "58JH7RHQ+C5"
#             },
#             "rating": 3.2,
#             "reference": "ChIJKRi9fOAFp5QRbrdBK8vcntA",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 27,
#             "vicinity": "Rua Coronel Jos\u00e9 Reginaldo, 3 - Centro, Ipameri"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -17.7242043,
#                     "lng": -48.1631922
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -17.7228649197085,
#                         "lng": -48.1618135197085
#                     },
#                     "southwest": {
#                         "lat": -17.7255628802915,
#                         "lng": -48.16451148029149
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Hotel Dom Casmurro",
#             "place_id": "ChIJKSrNz8sFp5QRD33G_C0h0g0",
#             "plus_code": {
#                 "compound_code": "7RGP+8P Centro, Ipameri - GO, Brazil",
#                 "global_code": "58JH7RGP+8P"
#             },
#             "reference": "ChIJKSrNz8sFp5QRD33G_C0h0g0",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Rua General Mascarenhas de Morais - Centro, Ipameri"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -17.7174025,
#                     "lng": -48.16008249999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -17.7161282197085,
#                         "lng": -48.1586474697085
#                     },
#                     "southwest": {
#                         "lat": -17.7188261802915,
#                         "lng": -48.1613454302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Hotel Tropical",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2322,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/109830385614721225423\">Hamblam</a>"
#                     ],
#                     "photo_reference": "Aap_uEBfwPqlvCI13OAymQWNlP4d80nlTiveJPB6pUTX5zuw2vlW5kjopnW_RdbfIy4W6eqXH_7T4XSE3JGjRXD1u1fbYAa9ufFzJsQkaoWSmYSR1yOL6j5bQeH6O_jQsnvXNUIXVuhnaVKVJpRBSs1F1nUCJZqaXkDF4xQxN_y6BQxl_21j",
#                     "width": 4128
#                 }
#             ],
#             "place_id": "ChIJRRDN4-EFp5QR7_Jvj9svoVU",
#             "plus_code": {
#                 "compound_code": "7RMQ+2X Centro, Ipameri - GO, Brazil",
#                 "global_code": "58JH7RMQ+2X"
#             },
#             "rating": 4,
#             "reference": "ChIJRRDN4-EFp5QR7_Jvj9svoVU",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 154,
#             "vicinity": "Rua Coronel Jo\u00e3o Vaz, 69 - Centro, Ipameri"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -17.7157007,
#                     "lng": -48.1635129
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -17.7143771697085,
#                         "lng": -48.1621207197085
#                     },
#                     "southwest": {
#                         "lat": -17.7170751302915,
#                         "lng": -48.1648186802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Hotel dos Viajantes de Ipameri",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 960,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100641789905683673716\">Hotel dos Viajantes de Ipameri</a>"
#                     ],
#                     "photo_reference": "Aap_uEBYgJgBnKQU8Sf-FKOwwTLvigE7xYe1jMtUV9hEC4W8orARV3HK2iZl58kkDtB2H9GduhE0hsf_c6J70nvcxydok1Pu44FwiDHldpzXrdoJT2OctN6puV7xejLLN7CeUi-DNOP_SYm10zwGn9VjCu2YcZ0q_qA4hWp_byjKxAFNH0g1",
#                     "width": 1280
#                 }
#             ],
#             "place_id": "ChIJuQzx4KIFp5QRlLyXwbs1a8s",
#             "plus_code": {
#                 "compound_code": "7RMP+PH Dom Vital, Ipameri - GO, Brazil",
#                 "global_code": "58JH7RMP+PH"
#             },
#             "rating": 4.9,
#             "reference": "ChIJuQzx4KIFp5QRlLyXwbs1a8s",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 54,
#             "vicinity": "Avenida Nossa Senhora da Aparecida, n12 - Dom Vital, Ipameri"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -17.7298232,
#                     "lng": -48.1621296
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -17.7284325697085,
#                         "lng": -48.1607813197085
#                     },
#                     "southwest": {
#                         "lat": -17.7311305302915,
#                         "lng": -48.1634792802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Hotel Tilaninho",
#             "place_id": "ChIJQ6MHTdgFp5QRQxtDspCmNOM",
#             "plus_code": {
#                 "compound_code": "7RCQ+34 Novo Horizonte, Ipameri - GO, Brazil",
#                 "global_code": "58JH7RCQ+34"
#             },
#             "rating": 3.7,
#             "reference": "ChIJQ6MHTdgFp5QRQxtDspCmNOM",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 10,
#             "vicinity": "Brazil"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -17.7224244,
#                     "lng": -48.1506892
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -17.72107541970849,
#                         "lng": -48.1493402197085
#                     },
#                     "southwest": {
#                         "lat": -17.7237733802915,
#                         "lng": -48.1520381802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Pousada Da Peu",
#             "place_id": "ChIJxY72bHIGp5QR4qEZAveNq8w",
#             "plus_code": {
#                 "compound_code": "7RHX+2P Sn, Ipameri - GO, Brazil",
#                 "global_code": "58JH7RHX+2P"
#             },
#             "rating": 2.9,
#             "reference": "ChIJxY72bHIGp5QR4qEZAveNq8w",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 7,
#             "vicinity": "Doutor, Rua Miguel Lopes Vaz - Sn, Ipameri"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -17.7138372,
#                     "lng": -48.1465499
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -17.7124397697085,
#                         "lng": -48.1452315197085
#                     },
#                     "southwest": {
#                         "lat": -17.7151377302915,
#                         "lng": -48.1479294802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Cas Dos Pedreiros",
#             "place_id": "ChIJ8SrvxBMGp5QR_tzHJutHS_k",
#             "plus_code": {
#                 "compound_code": "7VP3+F9 Vila Peixoto, Ipameri - GO, Brazil",
#                 "global_code": "58JH7VP3+F9"
#             },
#             "rating": 5,
#             "reference": "ChIJ8SrvxBMGp5QR_tzHJutHS_k",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "Brazil"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -17.7360738,
#                     "lng": -48.16600580000001
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -17.7346262697085,
#                         "lng": -48.1647225197085
#                     },
#                     "southwest": {
#                         "lat": -17.7373242302915,
#                         "lng": -48.1674204802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png",
#             "name": "Chopp Hotel Tilaninho",
#             "photos": [
#                 {
#                     "height": 581,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/112347764218784873664\">Mbloom Ag\u00eancia Digital</a>"
#                     ],
#                     "photo_reference": "Aap_uECn_78cFXefRegq5SwtmlAmXkIYPSwyO-JBjtmoLyoS11WfReVGE-pkbdxfzzTelblVjznCr-uEbKHYl_v3cgc_S7zw-9jdgl0SAQ7QbUgjZANU3CX_1KULUmJTptyOVNKbt-5ewYX7hxtwBTsQXOOqQ9N0QGAWr-7bijimo7aaX5Dj",
#                     "width": 1032
#                 }
#             ],
#             "place_id": "ChIJTekb4goGp5QRSvzLSr_kF3U",
#             "plus_code": {
#                 "compound_code": "7R7M+HH Village Sul, Ipameri - GO, Brazil",
#                 "global_code": "58JH7R7M+HH"
#             },
#             "rating": 4.1,
#             "reference": "ChIJTekb4goGp5QRSvzLSr_kF3U",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "bar",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 65,
#             "vicinity": "Rodovia 330 Trevo Sul - encima - Village Sul, Ipameri"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -17.7383162,
#                     "lng": -48.1633923
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -17.7370921197085,
#                         "lng": -48.1620915197085
#                     },
#                     "southwest": {
#                         "lat": -17.7397900802915,
#                         "lng": -48.1647894802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Tilaninho Turismo Hotel",
#             "photos": [
#                 {
#                     "height": 2988,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101817646329556203260\">rui barbachan</a>"
#                     ],
#                     "photo_reference": "Aap_uEDbnzePm7AcECoPCEmJJHCu3YkHsvj0UMMZSRSC1uVHLg7PNrTbYt1jfpQZMnMdBKgJyTM8xGEsskouTWHsj6hvFZZ_jIPLyQJc0aYvdvJHeP22RsIP9uN00Py14_Rffgp32KOTlh4m_leB7mF-m4rYmXCLxIz_OQFi57NtEbov1mH7",
#                     "width": 5312
#                 }
#             ],
#             "place_id": "ChIJ7-WNjAoGp5QR0JATDjoyjSw",
#             "plus_code": {
#                 "compound_code": "7R6P+MJ Village Sul, Ipameri - GO, Brazil",
#                 "global_code": "58JH7R6P+MJ"
#             },
#             "rating": 3.8,
#             "reference": "ChIJ7-WNjAoGp5QR0JATDjoyjSw",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 77,
#             "vicinity": "Rod. Jk Trevo Sul, s/n - Village Sul, Ipameri"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -17.7037012,
#                     "lng": -48.1616485
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -17.7023643697085,
#                         "lng": -48.1603633697085
#                     },
#                     "southwest": {
#                         "lat": -17.7050623302915,
#                         "lng": -48.1630613302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Pousada Ouro Verde",
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111478765813114517712\">Fernando Fernandes</a>"
#                     ],
#                     "photo_reference": "Aap_uEDOmykcnI0YPXI_ZszG8-qMelWRd1Zoylp7mLTh-FPhOCd5WRAlJRIoseqt9tCdDaVjucNsO1rxr4DVlYmpCrV-vim_Eiv6z2sGFXUAOoVzt_vZ4OUYtaiZPKTLn7pBqjzgaycDdiFoDooU1MQp3xn82MhbX66m0JE9P3iWbhwZM4mc",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJdbvEvv8Fp5QRvcULlWex4QM",
#             "plus_code": {
#                 "compound_code": "7RWQ+G8 Jardim Adelaide, Ipameri - GO, Brazil",
#                 "global_code": "58JH7RWQ+G8"
#             },
#             "rating": 4.4,
#             "reference": "ChIJdbvEvv8Fp5QRvcULlWex4QM",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 170,
#             "vicinity": "Jardim Adelaide, Ipameri"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -17.6973323,
#                     "lng": -48.1763085
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -17.6959934697085,
#                         "lng": -48.1749421197085
#                     },
#                     "southwest": {
#                         "lat": -17.6986914302915,
#                         "lng": -48.1776400802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Resort santa paula",
#             "place_id": "ChIJA69uS5EPp5QRnZCw7zo0f4o",
#             "plus_code": {
#                 "compound_code": "8R3F+3F Jardim Adelaide, Ipameri - GO, Brazil",
#                 "global_code": "58JH8R3F+3F"
#             },
#             "rating": 5,
#             "reference": "ChIJA69uS5EPp5QRnZCw7zo0f4o",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 4,
#             "vicinity": "Unnamed Road, Ipameri"
#         }
#     ],
#     "status": "OK"
# }
# --------------------------------livingston-----------------------------------------
# {
#     "html_attributions": [],
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 55.91548079999999,
#                     "lng": -3.526385899999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 55.9167106302915,
#                         "lng": -3.525159819708498
#                     },
#                     "southwest": {
#                         "lat": 55.9140126697085,
#                         "lng": -3.527857780291502
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Premier Inn Livingston (M8, Jct3) hotel",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 532,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/109667211351208374553\">Premier Inn Livingston (M8, Jct3) hotel</a>"
#                     ],
#                     "photo_reference": "Aap_uEC3MSBu5qiq-VLzEsSgcKVk1q9iMlUyZDiKsi3DoZERE6PWvLl4ZrzpCGCN8t9GvX6bMPQTlwEuZIyB3tdoHYyX9y5bYm22jQch1HSRIqJsFe_n5giqJELT3z0B-1vrMh15g5ztyV7QCQgbU_IOiQPua1x3Isfx2EaW_4TTaO4tk3As",
#                     "width": 798
#                 }
#             ],
#             "place_id": "ChIJL3gvQWLZh0gRc2Sll_xb66s",
#             "plus_code": {
#                 "compound_code": "WF8F+5C Livingston, UK",
#                 "global_code": "9C7RWF8F+5C"
#             },
#             "rating": 4.2,
#             "reference": "ChIJL3gvQWLZh0gRc2Sll_xb66s",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 566,
#             "vicinity": "Deer Park Avenue, Deer Park Drive, Livingston"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 55.89862729999999,
#                     "lng": -3.5309603
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 55.9000024802915,
#                         "lng": -3.529835519708499
#                     },
#                     "southwest": {
#                         "lat": 55.8973045197085,
#                         "lng": -3.532533480291502
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Livingston Lodge Hotel",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1367,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/116434836093100568616\">Livingston Lodge Hotel</a>"
#                     ],
#                     "photo_reference": "Aap_uEA7kBqSuK-amxWseNB7gTqHRuENJl_Nr4wD2espq2rEOsZB3ZKiVc4yqfOftU49STXEsBFsEyljvYS3NfuTFJAlXEJv7jgvl_eSwB9l33GhJevP_VFlyRFAPPFkXrjSbCwpAwAWsSz5KVB04SP-ad8WPf6rIwXkyGRLYgC09RbP0tQB",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJTaNkTlrZh0gRIeGxqTJF2R0",
#             "plus_code": {
#                 "compound_code": "VFX9+FJ Livingston, UK",
#                 "global_code": "9C7RVFX9+FJ"
#             },
#             "rating": 3.8,
#             "reference": "ChIJTaNkTlrZh0gRIeGxqTJF2R0",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 189,
#             "vicinity": "Hawk Brae, Livingston"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 55.8968922,
#                     "lng": -3.5041899
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 55.89821768029149,
#                         "lng": -3.503083669708498
#                     },
#                     "southwest": {
#                         "lat": 55.8955197197085,
#                         "lng": -3.505781630291501
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Auld 13",
#             "place_id": "ChIJs7tVIfDbh0gRkAPg3ZGejJc",
#             "plus_code": {
#                 "compound_code": "VFWW+Q8 Livingston, UK",
#                 "global_code": "9C7RVFWW+Q8"
#             },
#             "rating": 4.5,
#             "reference": "ChIJs7tVIfDbh0gRkAPg3ZGejJc",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 2,
#             "vicinity": "25 Inglewood Street, Livingston"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 55.8891784,
#                     "lng": -3.529917199999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 55.8904404302915,
#                         "lng": -3.528869769708498
#                     },
#                     "southwest": {
#                         "lat": 55.8877424697085,
#                         "lng": -3.531567730291502
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "PROVINCIAL GRAND LODGE OF LINLITHGOWSHIRE",
#             "place_id": "ChIJj-F7u1PZh0gR9d49GHvrspU",
#             "plus_code": {
#                 "compound_code": "VFQC+M2 Livingston, UK",
#                 "global_code": "9C7RVFQC+M2"
#             },
#             "rating": 3,
#             "reference": "ChIJj-F7u1PZh0gR9d49GHvrspU",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 2,
#             "vicinity": "49, Geddes House, Kirkton North Road, Livingston"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 55.9206547,
#                     "lng": -3.5229615
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 55.9220518802915,
#                         "lng": -3.521480919708498
#                     },
#                     "southwest": {
#                         "lat": 55.9193539197085,
#                         "lng": -3.524178880291502
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "The Loft",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "place_id": "ChIJQzRww9fbh0gRtD6PTcmD4sk",
#             "plus_code": {
#                 "compound_code": "WFCG+7R Broxburn, UK",
#                 "global_code": "9C7RWFCG+7R"
#             },
#             "reference": "ChIJQzRww9fbh0gRtD6PTcmD4sk",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "11 Houstoun Mains Holdings, Broxburn"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 55.90070799999999,
#                     "lng": -3.518068
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 55.9020569802915,
#                         "lng": -3.516719019708499
#                     },
#                     "southwest": {
#                         "lat": 55.8993590197085,
#                         "lng": -3.519416980291502
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Toll House",
#             "place_id": "ChIJHx4vDYrbh0gRohU0uTVoqyk",
#             "plus_code": {
#                 "compound_code": "WF2J+7Q Livingston, UK",
#                 "global_code": "9C7RWF2J+7Q"
#             },
#             "reference": "ChIJHx4vDYrbh0gRohU0uTVoqyk",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Livingston"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 55.90849000000001,
#                     "lng": -3.520540700000001
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 55.9098440302915,
#                         "lng": -3.519092369708499
#                     },
#                     "southwest": {
#                         "lat": 55.9071460697085,
#                         "lng": -3.521790330291502
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Queen Lee lodge b&b",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 4000,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/118398898538630529214\">Queen Lee lodge b&amp;b</a>"
#                     ],
#                     "photo_reference": "Aap_uEDyeLEttkXjjgDchFHLY4m385c5wg-5ZQgLeQwMxx-kPONOob_IXaEtxsNFHpa_xyj62Mv9q1R4xnIeUYqIRcdmnWT5WB4Zf5mPm1pxaGElEi-4COU2_dAh7ngmceAeZE9hHO_nx9uL-5allIbacPmOimgkN-S8URiN4Ms8_hr-BzD9",
#                     "width": 6016
#                 }
#             ],
#             "place_id": "ChIJJV0wCirbh0gR-bU34QzA6tY",
#             "plus_code": {
#                 "compound_code": "WF5H+9Q Livingston, UK",
#                 "global_code": "9C7RWF5H+9Q"
#             },
#             "reference": "ChIJJV0wCirbh0gR-bU34QzA6tY",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "23 Davidson Way, Livingston"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 55.9130522,
#                     "lng": -3.534335999999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 55.91437163029151,
#                         "lng": -3.533489369708498
#                     },
#                     "southwest": {
#                         "lat": 55.91167366970851,
#                         "lng": -3.536187330291501
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Knightsridge House Apartment",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2173,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104460872358800926415\">Knightsridge House Apartment</a>"
#                     ],
#                     "photo_reference": "Aap_uEA9HdnDjbcwXDVV2iVuBGWAET-_Fslbh1t-KrITJFHRN2iLKyhftHfBOBDBSaQOXYpaQh7aqDbjR9d-eJ9ldaZ_ImFu_C3q__6ut4vaOrlJUr2HF_UC60g-47lkhGwlSxejO0f1nPNJfvcSaY7Hu54VlrMMqLoC0HZh7sr_B2h2uJ4R",
#                     "width": 3267
#                 }
#             ],
#             "place_id": "ChIJ_0l5HV_Zh0gRN0Agtyt1qac",
#             "plus_code": {
#                 "compound_code": "WF78+67 Livingston, UK",
#                 "global_code": "9C7RWF78+67"
#             },
#             "rating": 4.7,
#             "reference": "ChIJ_0l5HV_Zh0gRN0Agtyt1qac",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 3,
#             "vicinity": "Knightsridge House, Deer Park, Watson Green, Livingston"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 55.91537899999999,
#                     "lng": -3.5271949
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 55.91672798029149,
#                         "lng": -3.525867719708498
#                     },
#                     "southwest": {
#                         "lat": 55.91403001970849,
#                         "lng": -3.528565680291502
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Premier Inn Livingston",
#             "place_id": "ChIJg1UmsmPZh0gRuW_4js0hXpY",
#             "plus_code": {
#                 "compound_code": "WF8F+54 Livingston, UK",
#                 "global_code": "9C7RWF8F+54"
#             },
#             "reference": "ChIJg1UmsmPZh0gRuW_4js0hXpY",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Deer Park Avenue, Livingston"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 55.90131419999999,
#                     "lng": -3.5469072
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 55.9026023302915,
#                         "lng": -3.545513419708498
#                     },
#                     "southwest": {
#                         "lat": 55.8999043697085,
#                         "lng": -3.548211380291502
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Hasika Homes Executive Apartment",
#             "place_id": "ChIJ-fTgGoXZh0gR0JyPP8oPddM",
#             "plus_code": {
#                 "compound_code": "WF23+G6 Livingston, UK",
#                 "global_code": "9C7RWF23+G6"
#             },
#             "reference": "ChIJ-fTgGoXZh0gR0JyPP8oPddM",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "68 Carmondean Centre South, Deans, Livingston"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 55.9093633,
#                     "lng": -3.495786
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 55.9107536302915,
#                         "lng": -3.494312969708499
#                     },
#                     "southwest": {
#                         "lat": 55.9080556697085,
#                         "lng": -3.497010930291502
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Livingston-Contractor & Holiday Accommodation (Callum Apartment)",
#             "place_id": "ChIJFd9cijfbh0gRh-3k-sRiHb8",
#             "plus_code": {
#                 "compound_code": "WG53+PM Livingston, UK",
#                 "global_code": "9C7RWG53+PM"
#             },
#             "reference": "ChIJFd9cijfbh0gRh-3k-sRiHb8",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "149 Uphall Station Road, Livingston"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 55.8865691,
#                     "lng": -3.5253792
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 55.8879653302915,
#                         "lng": -3.524031019708498
#                     },
#                     "southwest": {
#                         "lat": 55.8852673697085,
#                         "lng": -3.526728980291501
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Almondvale road stadium view",
#             "photos": [
#                 {
#                     "height": 3174,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/113233468015646164376\">Sarah Jane Meikle</a>"
#                     ],
#                     "photo_reference": "Aap_uEBXpnNzA-ZefIVY7xRnXVUtlDHYsDCC86IGT6n6prAbdsA-GMnae0YPZdGKwuYICdZRiJdrO56_lo8edtnncmUow87aEiU2RTAfVzCnMt0ueDqnAKOX0kPNlx1WEnzBgkeRXXHyB7xA5L2dWOUq7nXEZk7zrPkT873Pxq5AF4XqXFRT",
#                     "width": 2834
#                 }
#             ],
#             "place_id": "ChIJsR1NrOjZh0gRqPPbqd5fcxc",
#             "plus_code": {
#                 "compound_code": "VFPF+JR Livingston, UK",
#                 "global_code": "9C7RVFPF+JR"
#             },
#             "rating": 5,
#             "reference": "ChIJsR1NrOjZh0gRqPPbqd5fcxc",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "Almondvale Avenue, Livingston"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 55.9076311,
#                     "lng": -3.4929833
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 55.90891798029149,
#                         "lng": -3.491792969708498
#                     },
#                     "southwest": {
#                         "lat": 55.9062200197085,
#                         "lng": -3.494490930291502
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Lothian Letting Places",
#             "place_id": "ChIJYSQBNpXbh0gRqEE2zj2vjMo",
#             "plus_code": {
#                 "compound_code": "WG54+3R Livingston, UK",
#                 "global_code": "9C7RWG54+3R"
#             },
#             "rating": 5,
#             "reference": "ChIJYSQBNpXbh0gRqEE2zj2vjMo",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "80 Uphall Station Road, Pumpherston, Livingston"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 55.9134002,
#                     "lng": -3.497309
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 55.9146349302915,
#                         "lng": -3.49653175
#                     },
#                     "southwest": {
#                         "lat": 55.9119369697085,
#                         "lng": -3.49964075
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Dundas",
#             "place_id": "ChIJMxrGDcXbh0gRye1qskfKvOo",
#             "plus_code": {
#                 "compound_code": "WG73+93 Livingston, UK",
#                 "global_code": "9C7RWG73+93"
#             },
#             "rating": 5,
#             "reference": "ChIJMxrGDcXbh0gRye1qskfKvOo",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "67 James Young Avenue, Uphall Station, Livingston"
#         }
#     ],
#     "status": "OK"
# }
# --------------------------------ondjiva-----------------------------------------
# {
#     "html_attributions": [],
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -17.065264,
#                     "lng": 15.7250709
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -17.0639306697085,
#                         "lng": 15.7263528802915
#                     },
#                     "southwest": {
#                         "lat": -17.0666286302915,
#                         "lng": 15.7236549197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "SOS Motel",
#             "place_id": "ChIJ5xR9v41glBsRsr2CeK_WmII",
#             "plus_code": {
#                 "compound_code": "WPMG+V2 Ondjiva, Angola",
#                 "global_code": "5FJQWPMG+V2"
#             },
#             "rating": 3.2,
#             "reference": "ChIJ5xR9v41glBsRsr2CeK_WmII",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 23,
#             "vicinity": "Ondjiva"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -17.0898984,
#                     "lng": 15.7472639
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -17.0886022197085,
#                         "lng": 15.7485264302915
#                     },
#                     "southwest": {
#                         "lat": -17.0913001802915,
#                         "lng": 15.7458284697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Pens\u00e3o Maroka",
#             "photos": [
#                 {
#                     "height": 3120,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101297087529962438919\">Aristides Gerardo Valdes Jaime</a>"
#                     ],
#                     "photo_reference": "Aap_uECuoSBzlImb_rgJledJ9D31sFipX-CfvnZfN3MEmn-5xp4ejM21URNm8b2HR-ImdJhQd0kOlaBDYkGr2dArt63MqEfx1xQkMedTXYRVoNsDLMTk2DjfrCwMGgOAUR3i0-1HaCdDGPlTLtKIeHFfalPCK2GPb9Cyfk1_lboSrvNj4OJx",
#                     "width": 4160
#                 }
#             ],
#             "place_id": "ChIJ89wvWk1glBsRNLkGFpmcc1I",
#             "plus_code": {
#                 "compound_code": "WP6W+2W Ondjiva, Angola",
#                 "global_code": "5FJQWP6W+2W"
#             },
#             "rating": 3.4,
# ...
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 36,
#             "vicinity": "Avenida Comercial, 528 - Centro, Pontalina"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -17.5234231,
#                     "lng": -49.4488744
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -17.5220788197085,
#                         "lng": -49.4475588197085
#                     },
#                     "southwest": {
#                         "lat": -17.5247767802915,
#                         "lng": -49.4502567802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Hotel do Gordo",
#             "place_id": "ChIJ-VPfedOGX5MR-wXGbB6XBQM",
#             "plus_code": {
#                 "compound_code": "FHG2+JF Pontalina - State of Goi\u00e1s, Brazil",
#                 "global_code": "58JGFHG2+JF"
#             },
#             "reference": "ChIJ-VPfedOGX5MR-wXGbB6XBQM",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Avenida Comercial, 516, Pontalina"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -17.5229642,
#                     "lng": -49.44336279999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -17.5216122197085,
#                         "lng": -49.4419720697085
#                     },
#                     "southwest": {
#                         "lat": -17.5243101802915,
#                         "lng": -49.4446700302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "O\u00e1sis Motel",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 518,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/116351295762267221410\">O\u00e1sis Motel</a>"
#                     ],
#                     "photo_reference": "Aap_uECqtGVgJq4_Lj3EUPhXSIDVFGAfVyHdKQUNoDwikyEeDBiKKLt7ebE-YUwPuwihzSg0GyICmbwtICUArX2ytzAiPtud7VwgmjFi0Vn4DYQkggrQ88fRfBO67Nxdb2QKsx7p3noq6mBd2xCepQNEIc4XvxCTXR535IVMBYsa5ZTyYPZo",
#                     "width": 1028
#                 }
#             ],
#             "place_id": "ChIJb5uUyXqBX5MRc3TB1ZZQmqI",
#             "plus_code": {
#                 "compound_code": "FHG4+RM Pontalina - State of Goi\u00e1s, Brazil",
#                 "global_code": "58JGFHG4+RM"
#             },
#             "rating": 1,
#             "reference": "ChIJb5uUyXqBX5MRc3TB1ZZQmqI",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "Avenida C Quadra 2, Lote 2 - Pontal Parque, Pontalina"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -17.5229622,
#                     "lng": -49.4433629
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -17.5216102197085,
#                         "lng": -49.4419721697085
#                     },
#                     "southwest": {
#                         "lat": -17.5243081802915,
#                         "lng": -49.44467013029149
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Oasis",
#             "photos": [
#                 {
#                     "height": 2340,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110437140777571183430\">Aguinel Barbosa</a>"
#                     ],
#                     "photo_reference": "Aap_uEDhzHbUHi-m04yTKZnmY9T-O5Aka7yFYsXeX6HMJ1cWU_e5hxhMOVgWoawMLcM-yjHrrJ8-MpkVrvMNfs1FCjw4vPlMQbidJ3VXeg32auTKSo3rUZ8D6widl-6CpLsDwp4714_GGMHQXCgpchvMq1vezcl7hdGVwiOYcLEn0z0FHqIO",
#                     "width": 4160
#                 }
#             ],
#             "place_id": "ChIJz_Tz8dOAX5MRrC9PZo_4rsw",
#             "plus_code": {
#                 "compound_code": "FHG4+RM Pontalina - State of Goi\u00e1s, Brazil",
#                 "global_code": "58JGFHG4+RM"
#             },
#             "rating": 4,
#             "reference": "ChIJz_Tz8dOAX5MRrC9PZo_4rsw",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 20,
#             "vicinity": "GO-040, Pontalina"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -17.5215652,
#                     "lng": -49.4552146
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -17.5202162197085,
#                         "lng": -49.45386561970849
#                     },
#                     "southwest": {
#                         "lat": -17.5229141802915,
#                         "lng": -49.45656358029149
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Hotel PRAIA FORMOSA",
#             "place_id": "ChIJ30qEAgGHX5MRJ61qrIMNBgQ",
#             "plus_code": {
#                 "compound_code": "FGHV+9W Pontalina - State of Goi\u00e1s, Brazil",
#                 "global_code": "58JGFGHV+9W"
#             },
#             "rating": 4.5,
#             "reference": "ChIJ30qEAgGHX5MRJ61qrIMNBgQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 2,
#             "vicinity": "Rua MG, Pontalina"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -17.5168435,
#                     "lng": -49.450818
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -17.5155238697085,
#                         "lng": -49.4494649197085
#                     },
#                     "southwest": {
#                         "lat": -17.5182218302915,
#                         "lng": -49.4521628802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Brisa",
#             "place_id": "ChIJQ5cXMcyGX5MRsEgyFUqh15M",
#             "plus_code": {
#                 "compound_code": "FGMX+7M Pontalina - State of Goi\u00e1s, Brazil",
#                 "global_code": "58JGFGMX+7M"
#             },
#             "rating": 5,
#             "reference": "ChIJQ5cXMcyGX5MRsEgyFUqh15M",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "Brazil"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -17.5167101,
#                     "lng": -49.4436691
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -17.5153611197085,
#                         "lng": -49.4423200197085
#                     },
#                     "southwest": {
#                         "lat": -17.5180590802915,
#                         "lng": -49.4450179802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Fique Bonita",
#             "place_id": "ChIJy5lfZzKBX5MRvwxXBdpq7F4",
#             "plus_code": {
#                 "compound_code": "FHM4+8G Pontalina - State of Goi\u00e1s, Brazil",
#                 "global_code": "58JGFHM4+8G"
#             },
#             "reference": "ChIJy5lfZzKBX5MRvwxXBdpq7F4",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Avenida A, Pontalina"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -17.5179208,
#                     "lng": -49.45674349999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -17.5164977697085,
#                         "lng": -49.4554074697085
#                     },
#                     "southwest": {
#                         "lat": -17.5191957302915,
#                         "lng": -49.4581054302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Calda Novo Hotel de Roma",
#             "place_id": "ChIJRXZaeQqHX5MRp3ActsRh6FI",
#             "plus_code": {
#                 "compound_code": "FGJV+R8 Pontalina - State of Goi\u00e1s, Brazil",
#                 "global_code": "58JGFGJV+R8"
#             },
#             "reference": "ChIJRXZaeQqHX5MRp3ActsRh6FI",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Pontalina"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -17.51527399999999,
#                     "lng": -49.4403076
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -17.5140279197085,
#                         "lng": -49.4389440697085
#                     },
#                     "southwest": {
#                         "lat": -17.5167258802915,
#                         "lng": -49.4416420302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "HOTEL BOA VISTA",
#             "place_id": "ChIJ7dVAcICBX5MROff80VuQKKM",
#             "plus_code": {
#                 "compound_code": "FHM5+VV Pontalina - State of Goi\u00e1s, Brazil",
#                 "global_code": "58JGFHM5+VV"
#             },
#             "rating": 4.6,
#             "reference": "ChIJ7dVAcICBX5MROff80VuQKKM",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 5,
#             "vicinity": "AVENIDA E NUMERO, 147 - VILA BRASIL, Pontalina"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -17.5113529,
#                     "lng": -49.4532767
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -17.5100052197085,
#                         "lng": -49.4519635197085
#                     },
#                     "southwest": {
#                         "lat": -17.5127031802915,
#                         "lng": -49.4546614802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Recanto das Araras",
#             "place_id": "ChIJ-6s1RCmHX5MR2VGKyoI6cEk",
#             "plus_code": {
#                 "compound_code": "FGQW+FM Pontalina - State of Goi\u00e1s, Brazil",
#                 "global_code": "58JGFGQW+FM"
#             },
#             "reference": "ChIJ-6s1RCmHX5MR2VGKyoI6cEk",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Rua Alameda dos Buritis, 51-1, Pontalina"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -17.509786,
#                     "lng": -49.44303999999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -17.5084460697085,
#                         "lng": -49.4417362197085
#                     },
#                     "southwest": {
#                         "lat": -17.5111440302915,
#                         "lng": -49.4444341802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Recanto dos Para\u00edbas",
#             "place_id": "ChIJDa5npWSBX5MRCYPQ0zJVSIA",
#             "plus_code": {
#                 "compound_code": "FHR4+3Q Pontalina - State of Goi\u00e1s, Brazil",
#                 "global_code": "58JGFHR4+3Q"
#             },
#             "reference": "ChIJDa5npWSBX5MRCYPQ0zJVSIA",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Avenida D, 8812, Pontalina"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -17.533058,
#                     "lng": -49.4631737
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -17.53114745,
#                         "lng": -49.4596742
#                     },
#                     "southwest": {
#                         "lat": -17.53878965000001,
#                         "lng": -49.4643402
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Fazenda Sao Lorenco",
#             "photos": [
#                 {
#                     "height": 2322,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114465731421941877423\">Weber Martins</a>"
#                     ],
#                     "photo_reference": "Aap_uEBcVUyT7VjccVVGCECNvmL2SUlzGU_j6HwZJ-7WzprnPFbIznuwlTbiYCeDbhoOcIxzfGkXJbCYfapPmEL9I4YkMbi9eB5pRZVyYOe98aFMTl7vL_2idDzwc2z1MdzjrT-D90TgZztN3zhtoxjcLYjpdXnhofuy0xB6O_eiJM5W4C05",
#                     "width": 4128
#                 }
#             ],
#             "place_id": "ChIJJ3HDlyCHX5MRIB1oHci7kMY",
#             "plus_code": {
#                 "compound_code": "FG8P+QP Pontalina - State of Goi\u00e1s, Brazil",
#                 "global_code": "58JGFG8P+QP"
#             },
#             "rating": 5,
#             "reference": "ChIJJ3HDlyCHX5MRIB1oHci7kMY",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "Pontalina"
#         }
#     ],
#     "status": "OK"
# }
# 5
